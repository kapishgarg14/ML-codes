# %% [markdown]
# **IMPORTS**

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_breast_cancer

# %%
X,y = load_breast_cancer(return_X_y = True, as_frame = True)

display(X.head())
display(y.head())

# %% [markdown]
# **TRAIN AND TEST SPLIT**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
display(X_train.shape)
display(y_train.shape)
display(X_test.shape)
display(y_test.shape)

# %% [markdown]
# **BAGGING**

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100)
clf = clf.fit(X_train, y_train)
y_pred_forest = clf.predict(X_test)
print('Random Forest Accuracy on test set : {0:0.4f}'. format(accuracy_score(y_test, y_pred_forest)))

# %% [markdown]
# **BOOSTING**

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier(n_estimators=100)
clf = clf.fit(X_train, y_train)
y_pred_ada = clf.predict(X_test)
print('AdaBoost Accuracy on test set : {0:0.4f}'. format(accuracy_score(y_test, y_pred_ada)))
